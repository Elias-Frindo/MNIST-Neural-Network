# %%
import numpy as np
import cv2
from PIL import Image
import pandas as pd
from matplotlib import pyplot as plt

# %%
params = np.load("model.npy", allow_pickle=True).item()

W1 = params["W1"]
b1 = params["b1"]
W2 = params["W2"]
b2 = params["b2"]

# %%
from PIL import Image
import numpy as np

# get raw image convert it to grey scale and resize it

R_img = Image.open('digit2.png').convert('L').resize((28, 28))

array_2d = np.array(R_img)
print(array_2d.shape)

array_1d = array_2d.reshape(-1)
print(array_1d.shape)

M_img = array_1d / 255
print(M_img)

# %%
def ReLU(Z):
    return np.maximum(Z, 0)

def softmax(Z):
    A = np.exp(Z) / sum(np.exp(Z))
    return A

def forward_prop(X, params):
    W1, b1 = params["W1"], params["b1"]
    W2, b2 = params["W2"], params["b2"]

    Z1 = W1.dot(X) + b1
    A1 = ReLU(Z1)
    Z2 = W2.dot(A1) + b2
    A2 = softmax(Z2)
    return Z1

# %%
probs = forward_prop(x, params)
# Get predicted digit
prediction = np.argmax(probs)
print("Predicted digit:", prediction)
# Out:
# Predicted digit: 4
# C:\Users\Frindo Ilyass\AppData\Local\Temp\ipykernel_6872\3719228889.py:5: RuntimeWarning: overflow encountered in exp
#   A = np.exp(Z) / sum(np.exp(Z))
# C:\Users\Frindo Ilyass\AppData\Local\Temp\ipykernel_6872\3719228889.py:5: RuntimeWarning: invalid value encountered in divide
#   A = np.exp(Z) / sum(np.exp(Z))
